# %%
import json

# %%
inventoryRead = open('Record.json','r')
Data = inventoryRead.read()
inventoryRead.close()

# %%
salesReader = open('Sales.json', 'r')
boughtProductsT = json.loads(salesReader.read())
salesReader.close()

# %%
readableData = json.loads(Data)
frame = list()
for i in readableData.keys():
    frame.append(i)

# %%
TransactionID = int(max(boughtProductsT.keys()))

# %%
boughtProducts = {}
print('{:12} {:25}       {:15}{:30}'.format('Product ID','Name','Price(Rs)','Weight (grams)'))
for ID in frame:
    print('  {:10} {:25} {:10}/-                {}gm\n'.format(ID,readableData[ID]['Name'],readableData[ID]['Price'],readableData[ID]['Weight (grams)']))
print('Above is the list of products')
while True:
    Id = input('Enter the ID of product to be bought : ')
    vAlue = Id in frame
    if vAlue == True:
        print('\nName:{}\tPrice:{}/-\tQauntity Available:{}'.format(readableData[Id]['Name'],readableData[Id]['Price'],readableData[Id]['Quantity']))
        quant = int(input('Enter the quantity of product you want to buy : '))
        if quant <= readableData[Id]['Quantity']:
            readableData[Id]['Quantity'] = readableData[Id]['Quantity'] - quant
            TransactionID += 1
            k = Id in boughtProducts.keys()
            if k == True:
                boughtProducts[Id]['Quantity Sold'] = boughtProducts[Id]['Quantity Sold'] + quant
                boughtProducts[Id]['Amount'] = boughtProducts[Id]['Amount'] + quant*boughtProducts[Id]['Price']
            else:
                boughtProducts[Id] = {'Name' : readableData[Id]['Name'], 'Weight (grams)' : readableData[Id]['Weight (grams)'], 'Price' : readableData[Id]['Price'], 'Quantity Sold' : quant,'Amount' : readableData[Id]['Price']*quant}
            boughtProductsT[TransactionID] = {'Name' : readableData[Id]['Name'], 'Weight (grams)' : readableData[Id]['Weight (grams)'], 'Price' : readableData[Id]['Price'], 'Quantity Sold' : quant,'Amount' : readableData[Id]['Price']*quant}
            print('\n{:25}         {:12}{:20}{:8}'.format('Name','Price','Quantity Ordered','Amount'))
            for i in boughtProducts.keys():
                print('{:25}{:12}{:20}      {:8}'.format(boughtProducts[i]['Name'],boughtProducts[i]['Price'],boughtProducts[i]['Quantity Sold'],boughtProducts[i]['Amount']))
            quest = input('\nIf you want to buy more products press enter or type \'Q\' to generate final bill : ')
            if quest.lower() == 'q':
                      break
        else:
            print('Entered quantity is greater than the available quantity.\nEnter quantity based on availability.')
    else:
        print('Entered Product ID is not available')
print('\n{:25}         {:12}{:20}{:8}'.format('Name','Price','Quantity Ordered','Amount'))
for i in boughtProducts.keys():
    print('{:25}{:12}{:20}      {:8}'.format(boughtProducts[i]['Name'],boughtProducts[i]['Price'],boughtProducts[i]['Quantity Sold'],boughtProducts[i]['Amount']))
TotalAmount = 0
for a in boughtProducts.keys():
    TotalAmount = TotalAmount + boughtProducts[a]['Amount'] 
print('\n{:25}{:28}{:5}     {:8}'.format(' ', ' ', 'Total', TotalAmount))
print('Total amount to be paid is {}'.format(TotalAmount))
# Out:
# Product ID   Name                            Price(Rs)      Weight (grams)
#   1101       Parle-G                           10/-                55gm
#
#   1102       Marie Gold                        30/-                200gm
#
#   1103       Vita Marie Gold                   40/-                240gm
#
#   1104       Hide&Seek ChocoChips              35/-                115gm
#
#   1105       Dark Fantasy                      30/-                80gm
#
#   1106       Oreo                              40/-                110gm
#
#   1107       Fab                               25/-                60gm
#
#   1108       Jim-Jam                           20/-                70gm
#
#   1109       Treat                             10/-                45gm
#
#   1110       Bounce Cream                       5/-                45gm
#
#   1111       Bourbon                           30/-                120gm
#
#   1112       Nutrichoice Digestive             20/-                75gm
#
#   1113       Unibic                            25/-                60gm
#
#   1114       Krackjack                         10/-                60gm
#
#   1115       20-20 Cookies                      5/-                30gm
#
#   1116       Magix                              5/-                45gm
#
#   1117       Milk Shakti                       10/-                55gm
#
#   1118       MilkBikis                         10/-                55gm
#
#   1119       Tiger                             10/-                55gm
#
#   1120       GoodDay                           35/-                135gm
#
#   1121       Little Hearts                     15/-                35gm
#
#   1122       50-50 Sweet n Salty               10/-                65gm
#
#   1123       Nice-Time                         20/-                90gm
#
#   1124       Snacky                            10/-                50gm
#
#   1125       Cheese Cracker                    15/-                55gm
#
#   1126       Hide&Seek Milano                  40/-                70gm
#
#   1127       Happy Happy                       25/-                125gm
#
#   1128       Coconut Cookies                   10/-                65gm
#
#   1129       Top                               10/-                55gm
#
#   1130       Monaco                            10/-                40gm
#
#   1131       Googly                            95/-                160gm
#
#   1132       CNC                               10/-                60gm
#
#   1133       Classic cream                      5/-                40gm
#
#   1134       Countlines                        20/-                95gm
#
#   1135       Butter Bake                       55/-                150gm
#
# Above is the list of products
# Enter the ID of product to be bought : 1115
#
# Name:20-20 Cookies	Price:5/-	Qauntity Available:150
# Enter the quantity of product you want to buy : 40
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1134
#
# Name:Countlines	Price:20/-	Qauntity Available:150
# Enter the quantity of product you want to buy : 50
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1130
#
# Name:Monaco	Price:10/-	Qauntity Available:200
# Enter the quantity of product you want to buy : 100
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1112
#
# Name:Nutrichoice Digestive	Price:20/-	Qauntity Available:90
# Enter the quantity of product you want to buy : 10
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1118
#
# Name:MilkBikis	Price:10/-	Qauntity Available:55
# Enter the quantity of product you want to buy : 5
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1122
#
# Name:50-50 Sweet n Salty	Price:10/-	Qauntity Available:150
# Enter the quantity of product you want to buy : 50
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1105
#
# Name:Dark Fantasy	Price:30/-	Qauntity Available:50
# Enter the quantity of product you want to buy : 5
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1103
#
# Name:Vita Marie Gold	Price:40/-	Qauntity Available:100
# Enter the quantity of product you want to buy : 20
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
#
# If you want to buy more products press enter or type 'Q' to generate final bill : 1102
# Enter the ID of product to be bought : 1102
#
# Name:Marie Gold	Price:30/-	Qauntity Available:150
# Enter the quantity of product you want to buy : 50
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1127
#
# Name:Happy Happy	Price:25/-	Qauntity Available:200
# Enter the quantity of product you want to buy : 50
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                  50          1250
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1123
#
# Name:Nice-Time	Price:20/-	Qauntity Available:60
# Enter the quantity of product you want to buy : 20
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                  50          1250
# Nice-Time                          20                  20           400
#
# If you want to buy more products press enter or type 'Q' to generate final bill : 1127
# Enter the ID of product to be bought : 1127
#
# Name:Happy Happy	Price:25/-	Qauntity Available:150
# Enter the quantity of product you want to buy : 50
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  20           400
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1127
#
# Name:Happy Happy	Price:25/-	Qauntity Available:100
# Enter the quantity of product you want to buy : 120
# Entered quantity is greater than the available quantity.
# Enter quantity based on availability.
# Enter the ID of product to be bought : 1137
# Entered Product ID is not available
# Enter the ID of product to be bought : 1135
#
# Name:Butter Bake	Price:55/-	Qauntity Available:100
# Enter the quantity of product you want to buy : 25
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  20           400
# Butter Bake                        55                  25          1375
#
# If you want to buy more products press enter or type 'Q' to generate final bill : 1125
# Enter the ID of product to be bought : 1125
#
# Name:Cheese Cracker	Price:15/-	Qauntity Available:85
# Enter the quantity of product you want to buy : 25
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  20           400
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  25           375
#
# If you want to buy more products press enter or type 'Q' to generate final bill : 1121
# Enter the ID of product to be bought : 1121
#
# Name:Little Hearts	Price:15/-	Qauntity Available:135
# Enter the quantity of product you want to buy : 35
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  20           400
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  25           375
# Little Hearts                      15                  35           525
#
# If you want to buy more products press enter or type 'Q' to generate final bill : 1123
# Enter the ID of product to be bought : 1123
#
# Name:Nice-Time	Price:20/-	Qauntity Available:40
# Enter the quantity of product you want to buy : 20
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  40           800
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  25           375
# Little Hearts                      15                  35           525
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1123
#
# Name:Nice-Time	Price:20/-	Qauntity Available:20
# Enter the quantity of product you want to buy : 10
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  50          1000
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  25           375
# Little Hearts                      15                  35           525
#
# If you want to buy more products press enter or type 'Q' to generate final bill : 1126
# Enter the ID of product to be bought : 1126
#
# Name:Hide&Seek Milano	Price:40/-	Qauntity Available:120
# Enter the quantity of product you want to buy : 60
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  50          1000
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  25           375
# Little Hearts                      15                  35           525
# Hide&Seek Milano                   40                  60          2400
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1128
#
# Name:Coconut Cookies	Price:10/-	Qauntity Available:140
# Enter the quantity of product you want to buy : 40
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  50          1000
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  25           375
# Little Hearts                      15                  35           525
# Hide&Seek Milano                   40                  60          2400
# Coconut Cookies                    10                  40           400
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1133
#
# Name:Classic cream	Price:5/-	Qauntity Available:100
# Enter the quantity of product you want to buy : 95
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  50          1000
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  25           375
# Little Hearts                      15                  35           525
# Hide&Seek Milano                   40                  60          2400
# Coconut Cookies                    10                  40           400
# Classic cream                       5                  95           475
#
# If you want to buy more products press enter or type 'Q' to generate final bill : 1117
# Enter the ID of product to be bought : 1117
#
# Name:Milk Shakti	Price:10/-	Qauntity Available:45
# Enter the quantity of product you want to buy : 40
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  50          1000
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  25           375
# Little Hearts                      15                  35           525
# Hide&Seek Milano                   40                  60          2400
# Coconut Cookies                    10                  40           400
# Classic cream                       5                  95           475
# Milk Shakti                        10                  40           400
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1110
#
# Name:Bounce Cream	Price:5/-	Qauntity Available:150
# Enter the quantity of product you want to buy : 100
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  50          1000
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  25           375
# Little Hearts                      15                  35           525
# Hide&Seek Milano                   40                  60          2400
# Coconut Cookies                    10                  40           400
# Classic cream                       5                  95           475
# Milk Shakti                        10                  40           400
# Bounce Cream                        5                 100           500
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1109
#
# Name:Treat	Price:10/-	Qauntity Available:65
# Enter the quantity of product you want to buy : 60
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  50          1000
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  25           375
# Little Hearts                      15                  35           525
# Hide&Seek Milano                   40                  60          2400
# Coconut Cookies                    10                  40           400
# Classic cream                       5                  95           475
# Milk Shakti                        10                  40           400
# Bounce Cream                        5                 100           500
# Treat                              10                  60           600
#
# If you want to buy more products press enter or type 'Q' to generate final bill : 1129
# Enter the ID of product to be bought : 1129
#
# Name:Top	Price:10/-	Qauntity Available:80
# Enter the quantity of product you want to buy : 50
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  50          1000
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  25           375
# Little Hearts                      15                  35           525
# Hide&Seek Milano                   40                  60          2400
# Coconut Cookies                    10                  40           400
# Classic cream                       5                  95           475
# Milk Shakti                        10                  40           400
# Bounce Cream                        5                 100           500
# Treat                              10                  60           600
# Top                                10                  50           500
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1132
#
# Name:CNC	Price:10/-	Qauntity Available:200
# Enter the quantity of product you want to buy : 100
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  50          1000
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  25           375
# Little Hearts                      15                  35           525
# Hide&Seek Milano                   40                  60          2400
# Coconut Cookies                    10                  40           400
# Classic cream                       5                  95           475
# Milk Shakti                        10                  40           400
# Bounce Cream                        5                 100           500
# Treat                              10                  60           600
# Top                                10                  50           500
# CNC                                10                 100          1000
#
# If you want to buy more products press enter or type 'Q' to generate final bill :
# Enter the ID of product to be bought : 1131
#
# Name:Googly	Price:95/-	Qauntity Available:190
# Enter the quantity of product you want to buy : 100
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  50          1000
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  25           375
# Little Hearts                      15                  35           525
# Hide&Seek Milano                   40                  60          2400
# Coconut Cookies                    10                  40           400
# Classic cream                       5                  95           475
# Milk Shakti                        10                  40           400
# Bounce Cream                        5                 100           500
# Treat                              10                  60           600
# Top                                10                  50           500
# CNC                                10                 100          1000
# Googly                             95                 100          9500
#
# If you want to buy more products press enter or type 'Q' to generate final bill : 1125
# Enter the ID of product to be bought : 1125
#
# Name:Cheese Cracker	Price:15/-	Qauntity Available:60
# Enter the quantity of product you want to buy : 30
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  50          1000
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  55           825
# Little Hearts                      15                  35           525
# Hide&Seek Milano                   40                  60          2400
# Coconut Cookies                    10                  40           400
# Classic cream                       5                  95           475
# Milk Shakti                        10                  40           400
# Bounce Cream                        5                 100           500
# Treat                              10                  60           600
# Top                                10                  50           500
# CNC                                10                 100          1000
# Googly                             95                 100          9500
# If you want to buy more products press enter or type 'Q' to generate final bill : q
#
# Name                              Price       Quantity Ordered    Amount
# 20-20 Cookies                       5                  40           200
# Countlines                         20                  50          1000
# Monaco                             10                 100          1000
# Nutrichoice Digestive              20                  10           200
# MilkBikis                          10                   5            50
# 50-50 Sweet n Salty                10                  50           500
# Dark Fantasy                       30                   5           150
# Vita Marie Gold                    40                  20           800
# Marie Gold                         30                  50          1500
# Happy Happy                        25                 100          2500
# Nice-Time                          20                  50          1000
# Butter Bake                        55                  25          1375
# Cheese Cracker                     15                  55           825
# Little Hearts                      15                  35           525
# Hide&Seek Milano                   40                  60          2400
# Coconut Cookies                    10                  40           400
# Classic cream                       5                  95           475
# Milk Shakti                        10                  40           400
# Bounce Cream                        5                 100           500
# Treat                              10                  60           600
# Top                                10                  50           500
# CNC                                10                 100          1000
# Googly                             95                 100          9500
#
#                                                      Total        27400
# Total amount to be paid is 27400

# %%
salesGenerator = open('Sales.json', 'w')
salesGenerator.write(json.dumps(boughtProductsT, indent = 4))
salesGenerator.close()
print('Sales file has been generated')
# Out:
# Sales file has been generated

# %%
inventoryUpdate = open('Record.json', 'w')
inventoryUpdate.write(json.dumps(readableData, indent = 4))
inventoryUpdate.close()
